# %% [markdown]
# <a href="https://colab.research.google.com/github/Hunain513/week-1-ds-assignment/blob/main/Data_Science_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***SECTION B***

# %% [markdown]
# **DATA_SCIENCE_WEEK_1 ASSIGNEMNT**
#           **COVID-19 Dataset**

# %%
pip install kaggle

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-08d60654-30cb-40e2-93ac-215aa7d67a18" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08d60654-30cb-40e2-93ac-215aa7d67a18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d somin69/covid19-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/somin69/covid19-dataset
# License(s): unknown
# ...
# 100% 940k/940k [00:00<00:00, 996kB/s]

# %%
# !kaggle datasets download -d somin69/covid19-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/somin69/covid19-dataset
# License(s): unknown
# covid19-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# covid19-dataset.zip  kaggle.json  sample_data

# %%
# !unzip covid19-dataset.zip
# Out:
# Archive:  covid19-dataset.zip
#   inflating: Covid_Dataset.csv

# %%
# !ls
# Out:
# covid19-dataset.zip  Covid_Dataset.csv	kaggle.json  sample_data

# %% [markdown]
# # **Section C**

# %%
import pandas as pd

df = pd.read_csv("Covid_Dataset.csv")
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03-05-2020        3          1
# 1      2             1    2             1  03-06-2020        3          1
# 2      2             1    2             2  09-06-2020        1          2
# 3      2             1    1             1  12-06-2020        3          2
# 4      2             1    2             1  21-06-2020        3          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         0  ...       0        0             1              0
# 1   72         3         0  ...       0        0             1              0
# 2   55         3         1  ...       0        0             0              0
# 3   53         2         0  ...       0        0             0              0
# 4   68         3         1  ...       0        0             1              0
#
# ...

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 15)

df
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0           2             1    1             1  03-05-2020        3
# 1           2             1    2             1  03-06-2020        3
# 2           2             1    2             2  09-06-2020        1
# 3           2             1    1             1  12-06-2020        3
# 4           2             1    2             1  21-06-2020        3
# ...       ...           ...  ...           ...         ...      ...
# 199994      1             4    1             1  9999-99-99        3
# 199995      2             4    1             1  9999-99-99        3
# 199996      1             4    2             1  9999-99-99        3
# 199997      1             4    1             2  9999-99-99        2
# 199998      1             4    1             1  9999-99-99        3
#
#         PNEUMONIA  ...  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# ...

# %%
df.shape
# Out:
# (199999, 21)

# %% [markdown]
# After downloading kaggle dataset and accessing it to google colab , I extracted the downloaded dataset , and create a csv file because for pandas to access the file dataset , we need csv file. Pandas is a command that is used to read csv file . df(head) is used to display some rows and columns so that we can get the idea of our dataset. I used this command of pandas , pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 15)
#
# df
# to display 500 rows and 15 columns as mentioned in the assignemnt. df.shape , tells us how many rows and columns are in this dataset.

# %%
df.dtypes
# Out:
# USMER                    int64
# MEDICAL_UNIT             int64
# SEX                      int64
# PATIENT_TYPE             int64
# DATE_DIED               object
# INTUBED                  int64
# PNEUMONIA                int64
# AGE                      int64
# PREGNANT                 int64
# DIABETES                 int64
# COPD                     int64
# ASTHMA                   int64
# INMSUPR                  int64
# HIPERTENSION             int64
# OTHER_DISEASE            int64
# CARDIOVASCULAR           int64
# OBESITY                  int64
# RENAL_CHRONIC            int64
# TOBACCO                  int64
# CLASIFFICATION_FINAL     int64
# ICU                      int64
# dtype: object

# %% [markdown]
# This data set contains int 64 as a datatype. It can store numerical and whole number values. I think they didnt use patient names in this dataset , patient Id is also numerical and for gender 1 means male , 2 means female and 99 means unknown . They have used int64 , because it saves memory , and makes machine learning algorithms easier.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   USMER                 199999 non-null  int64
#  1   MEDICAL_UNIT          199999 non-null  int64
#  2   SEX                   199999 non-null  int64
#  3   PATIENT_TYPE          199999 non-null  int64
#  4   DATE_DIED             199999 non-null  object
#  5   INTUBED               199999 non-null  int64
#  6   PNEUMONIA             199999 non-null  int64
#  7   AGE                   199999 non-null  int64
#  8   PREGNANT              199999 non-null  int64
#  9   DIABETES              199999 non-null  int64
#  10  COPD                  199999 non-null  int64
#  11  ASTHMA                199999 non-null  int64
#  12  INMSUPR               199999 non-null  int64
#  13  HIPERTENSION          199999 non-null  int64
# ...

# %% [markdown]
# As u can see , Date_died is an object not int64 , because it contain string. It has zero Nan values . So we wont have any difficulty applying machine learning model training on it. Also if we see 1 it means yes this person is diabetic and 2 means No .

# %%
df.describe()
# Out:
#                USMER   MEDICAL_UNIT            SEX   PATIENT_TYPE  \
# count  199999.000000  199999.000000  199999.000000  199999.000000
# mean        1.560453       3.900170       1.523433       1.346587
# std         0.496333       0.309976       0.499452       0.475884
# min         1.000000       1.000000       1.000000       1.000000
# 25%         1.000000       4.000000       1.000000       1.000000
# 50%         2.000000       4.000000       2.000000       1.000000
# 75%         2.000000       4.000000       2.000000       2.000000
# max         2.000000       4.000000       2.000000       2.000000
#
#              INTUBED      PNEUMONIA            AGE  ...  OTHER_DISEASE  \
# count  199999.000000  199999.000000  199999.000000  ...  199999.000000
# mean        2.578108       4.095105      45.317002  ...       0.052340
# std         0.656066      14.817906      17.262120  ...       0.222713
# min         1.000000       1.000000       0.000000  ...       0.000000
# ...

# %% [markdown]
# This dataset contain categorial values , means patients details , It is not continous measurement so we wont be able to measure rightskewed and able to identify about outliers , but for different datasets we will be able to identify outliers according to mean and median values.

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %% [markdown]
# There is no missing values in this dataset.

# %%
df['DIABETES'].value_counts()
# Out:
# DIABETES
# 0    165406
# 1     34593
# Name: count, dtype: int64

# %% [markdown]
# For this command , 80 percent people have diabeties in this dataset and 17 percent are non- diabetic , means 17 percent people have more chance to recover with this illness soon. Also the class is imbalanced . 80 percent belong to class 0 and 17 percent to class 1.

# %%
df.duplicated().sum()
# Out:
# np.int64(125590)

# %% [markdown]
# This dataset contains 125590 duplicate rows , So total rows 199,999 - 125590 = 74,409 and np means numpy integer 64 , datatype for this output.

# %% [markdown]
# # Section D

# %%
df.head(10)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03-05-2020        3          1
# 1      2             1    2             1  03-06-2020        3          1
# 2      2             1    2             2  09-06-2020        1          2
# 3      2             1    1             1  12-06-2020        3          2
# 4      2             1    2             1  21-06-2020        3          2
# 5      2             1    1             2  9999-99-99        2          1
# 6      2             1    1             1  9999-99-99        3          2
# 7      2             1    1             1  9999-99-99        3          1
# 8      2             1    1             2  9999-99-99        2          2
# 9      2             1    1             2  9999-99-99        2          2
#
#    ...  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0  ...              0               0        0              0        0
# ...

# %% [markdown]
# Display first 10 rows

# %%
df.tail(5)
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 199994      1             4    1             1  9999-99-99        3
# 199995      2             4    1             1  9999-99-99        3
# 199996      1             4    2             1  9999-99-99        3
# 199997      1             4    1             2  9999-99-99        2
# 199998      1             4    1             1  9999-99-99        3
#
#         PNEUMONIA  ...  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 199994          2  ...              0               0        0              0
# 199995          2  ...              0               0        0              0
# 199996          2  ...              0               0        0              0
# 199997          2  ...              0               0        0              0
# 199998          2  ...              0               0        1              0
#
#         TOBACCO  CLASIFFICATION_FINAL  ICU
# 199994        0                     6    0
# ...

# %% [markdown]
# Last 5 rows

# %%
df.sample(15)
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 101555      1             4    1             1  9999-99-99        3
# 59071       1             4    1             2  15-08-2020        1
# 63611       1             4    1             1  9999-99-99        3
# 26700       2             4    1             2  11-05-2020        2
# 67080       2             4    2             1  9999-99-99        3
# 19865       2             4    2             2  29-02-2020        2
# 176458      1             4    2             1  9999-99-99        3
# 126154      2             4    1             2  9999-99-99        2
# 168725      1             4    2             1  9999-99-99        3
# 145705      1             4    2             1  9999-99-99        3
# 185927      2             4    1             1  9999-99-99        3
# 15457       2             3    2             2  9999-99-99        2
# 52061       1             4    1             2  09-07-2020        2
# ...

# %% [markdown]
# It displays 15 random rows

# %%
df.columns.tolist()
# Out:
# ['USMER',
#  'MEDICAL_UNIT',
#  'SEX',
#  'PATIENT_TYPE',
#  'DATE_DIED',
#  'INTUBED',
#  'PNEUMONIA',
#  'AGE',
#  'PREGNANT',
#  'DIABETES',
#  'COPD',
#  'ASTHMA',
#  'INMSUPR',
#  'HIPERTENSION',
#  'OTHER_DISEASE',
#  'CARDIOVASCULAR',
#  'OBESITY',
#  'RENAL_CHRONIC',
#  'TOBACCO',
#  'CLASIFFICATION_FINAL',
#  'ICU']

# %% [markdown]
# Display all columns names with their differences.

# %%
df.nunique()
# Out:
# USMER                     2
# MEDICAL_UNIT              4
# SEX                       2
# PATIENT_TYPE              2
# DATE_DIED               337
# INTUBED                   4
# PNEUMONIA                 3
# AGE                     105
# PREGNANT                  4
# DIABETES                  2
# COPD                      2
# ASTHMA                    2
# INMSUPR                   2
# HIPERTENSION              2
# OTHER_DISEASE             2
# CARDIOVASCULAR            2
# OBESITY                   2
# RENAL_CHRONIC             2
# TOBACCO                   2
# CLASIFFICATION_FINAL      7
# ICU                       2
# dtype: int64

# %% [markdown]
# 2 means , 2 unique values , 4 means 4 different medical units , 105 different ages.

# %%
df['DIABETES'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# 0 means no diabetes and 1 mean diabetes

# %%
df['CARDIOVASCULAR'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# same as diabetes , 0 means no cardivascular problem and 1 mean yes he has some cardiac issue.

# %%
df.corr(numeric_only=True)
# Out:
#                          USMER  MEDICAL_UNIT       SEX  PATIENT_TYPE  \
# USMER                 1.000000      0.065486 -0.021250     -0.181310
# MEDICAL_UNIT          0.065486      1.000000  0.030063      0.085009
# SEX                  -0.021250      0.030063  1.000000      0.120630
# PATIENT_TYPE         -0.181310      0.085009  0.120630      1.000000
# INTUBED               0.158386     -0.088205 -0.116089     -0.882964
# PNEUMONIA            -0.164585      0.006192 -0.019887     -0.083314
# AGE                  -0.080016      0.036395  0.050947      0.499520
# PREGNANT             -0.021798      0.029254  0.983934      0.117718
# DIABETES             -0.047271      0.028337  0.003571      0.292870
# COPD                 -0.018683      0.021232  0.003196      0.119549
# ASTHMA                0.009190     -0.008521 -0.052314     -0.032889
# INMSUPR              -0.007399      0.003120 -0.005646      0.090846
# HIPERTENSION         -0.042489      0.036740  0.002485      0.286577
# ...

# %% [markdown]
# This shows correlation between different values. The correlation between -1 to +1 ranges 0 mean no linear correlation between them. Only Patient type and ICU have 1 value and have perfect corelation between them

# %%
df['AGE'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# This shows histogram between all patient ages which is between 0 and 100 which have COVID-19.

# %%
df.groupby('ASTHMA').mean(numeric_only=True)
# Out:
#            USMER  MEDICAL_UNIT       SEX  PATIENT_TYPE   INTUBED  PNEUMONIA  \
# ASTHMA
# 0       1.559625      3.900649  1.528173      1.349426  2.574350   4.058561
# 1       1.585595      3.885611  1.379413      1.260317  2.692296   5.205398
#
#               AGE  ...  OTHER_DISEASE  CARDIOVASCULAR   OBESITY  \
# ASTHMA             ...
# 0       45.414371  ...       0.051031        0.024439  0.173138
# 1       42.358701  ...       0.092107        0.068884  0.289503
#
#         RENAL_CHRONIC   TOBACCO  CLASIFFICATION_FINAL       ICU
# ASTHMA
# 0            0.031447  0.074964              4.000398  0.349426
# 1            0.061666  0.109525              4.178095  0.260317
#
# [2 rows x 19 columns]

# %% [markdown]
# This command use asthma column and calculate its mean value.

# %%
df['PNEUMONIA'].value_counts(normalize=True)
# Out:
# PNEUMONIA
# 2     0.764654
# 1     0.211566
# 99    0.023780
# Name: proportion, dtype: float64

# %% [markdown]
# It contains proportion means 76 percent dont have PNEUMONIA and 21 percent have PNEUMONIA and rest of them are unknown.

# %%
df.select_dtypes(include='object')
# Out:
#          DATE_DIED
# 0       03-05-2020
# 1       03-06-2020
# 2       09-06-2020
# 3       12-06-2020
# 4       21-06-2020
# ...            ...
# 199994  9999-99-99
# 199995  9999-99-99
# 199996  9999-99-99
# 199997  9999-99-99
# 199998  9999-99-99
#
# [199999 rows x 1 columns]

# %%
df['DATE_DIED'].str.contains('pattern').sum()
# Out:
# np.int64(0)

# %%
df.sort_values('AGE',
ascending=False).head(5)
# Out:
#        USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 13022      1             3    1             1  9999-99-99        3          2
# 2360       2             3    2             2  9999-99-99        2          1
# 13023      1             3    1             1  9999-99-99        3          2
# 10732      2             3    1             1  9999-99-99        3          2
# 30062      1             4    2             2  20-05-2020        2          1
#
#        ...  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 13022  ...              0               0        0              0        1
# 2360   ...              0               0        0              0        0
# 13023  ...              0               0        0              0        0
# 10732  ...              0               0        0              0        0
# 30062  ...              1               0        0              0        0
#
#        CLASIFFICATION_FINAL  ICU
# ...

# %%
df[df['ASTHMA']>1]
# Out:
# Empty DataFrame
# Columns: [USMER, MEDICAL_UNIT, SEX, PATIENT_TYPE, DATE_DIED, INTUBED, PNEUMONIA, AGE, PREGNANT, DIABETES, COPD, ASTHMA, INMSUPR, HIPERTENSION, OTHER_DISEASE, CARDIOVASCULAR, OBESITY, RENAL_CHRONIC, TOBACCO, CLASIFFICATION_FINAL, ICU]
# Index: []
#
# [0 rows x 21 columns]

# %%
pd.pivot_table(df,values='AGE',index='ASTHMA',aggfunc='mean')
# Out:
#               AGE
# ASTHMA
# 0       45.414371
# 1       42.358701

# %%
df.memory_usage()
# Out:
# Index                       132
# USMER                   1599992
# MEDICAL_UNIT            1599992
# SEX                     1599992
# PATIENT_TYPE            1599992
# DATE_DIED               1599992
# INTUBED                 1599992
# PNEUMONIA               1599992
# AGE                     1599992
# PREGNANT                1599992
# DIABETES                1599992
# COPD                    1599992
# ASTHMA                  1599992
# INMSUPR                 1599992
# HIPERTENSION            1599992
# OTHER_DISEASE           1599992
# CARDIOVASCULAR          1599992
# OBESITY                 1599992
# RENAL_CHRONIC           1599992
# TOBACCO                 1599992
# CLASIFFICATION_FINAL    1599992
# ICU                     1599992
# dtype: int64

# %% [markdown]
# This displays the memory used for each column

# %%
df['ICU'].mode()
# Out:
# 0    0
# Name: ICU, dtype: int64

# %% [markdown]
# It simply means not many patients are admitted in ICU.
